# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
# Make a reference to the comic_books_expanded.csv file path
csv_path = "Esophageal Delim.csv"

# Import the comic_books_expanded.csv file as a DataFrame
books_df = pd.read_csv(csv_path, encoding="utf-8")
# Check the special characters imported correctly
books_df
# Out:
#          DATEDX  Age  Education  Sex       Region  Mstatus  Alcohol  Khat  \
# 0    12/14/2010   66          3    1       OROMIA        2        2     2
# 1     5/15/2010   66          3    2  ADDIS ABABA        2        2     1
# 2      2/2/2010   62          1    2  ADDIS ABABA        2        1     1
# 3     3/30/2010   62          1    2       OROMIA        2        1     2
# 4     4/15/2010   45          4    1       OROMIA        2        2     2
# ..          ...  ...        ...  ...          ...      ...      ...   ...
# 344    2/6/2016   55          3    2       OROMIA        2        2     1
# 345    2/9/2016   45          2    1        SNNPR        2        2     2
# 346   2/10/2016   67          2    2  ADDIS ABABA        2        2     1
# 347   3/21/2016   32          2    1       OROMIA        2        2     2
# 348    8/1/2016   58          2    2       AMHARA        2        1     1
#
#      Tobacco Comorbidity  ...  Chemotherapy  Chemo_type  Chemo_cycle  \
# 0          2           0  ...           0.0
# 1          2           0  ...           NaN         NaN          NaN
# 2          1           0  ...           NaN         NaN          NaN
# 3          2           0  ...           NaN         NaN          NaN
# 4          2           0  ...           NaN         NaN          NaN
# ..       ...         ...  ...           ...         ...          ...
# 344        2           0  ...           NaN         NaN          NaN
# 345        2           0  ...           NaN         NaN          NaN
# 346        2           0  ...           NaN         NaN          NaN
# 347        2           0  ...           NaN         NaN          NaN
# 348        1           0  ...           NaN         NaN          NaN
#
#      Radiotherapy  Radio_type  Hospital_stay    FU_last  Status_patient  \
# 0             0.0                        1.0  1/17/2011             2.0
# 1             NaN         NaN            NaN        NaN             NaN
# 2             NaN         NaN            NaN        NaN             NaN
# 3             NaN         NaN            NaN        NaN             NaN
# 4             NaN         NaN            NaN        NaN             NaN
# ..            ...         ...            ...        ...             ...
# 344           NaN         NaN            NaN        NaN             NaN
# 345           NaN         NaN            NaN        NaN             NaN
# 346           NaN         NaN            NaN        NaN             NaN
# 347           NaN         NaN            NaN        NaN             NaN
# 348           NaN         NaN            NaN        NaN             NaN
#
#      Date_death  Time_to_death
# 0     4/23/2011            1.0
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
# ..          ...            ...
# 344         NaN            NaN
# 345         NaN            NaN
# 346         NaN            NaN
# 347         NaN            NaN
# 348         NaN            NaN
#
# [349 rows x 47 columns]

# %%
# Remove unecessary columns from the DataFrame and save the new DataFrame
# Only keep: "ISBN", "Title", "Other titles", "Name", "All names", 
# "Country of publication", "Place of publication", "Publisher", "Date of publication"
reduced_df = books_df[["DATEDX", "Age", "Sex", "Region", "Alcohol", 
                       "Khat", "Tobacco", "Weight_loss", "Duration_all",
                       "Endoscopy", "CT_Scan", "Hist_grade", "Dist_metas", "Vomiting", "Heart_burn", "Cough",
                       "Chest_pain", "Ba_swallow", "Date_death"]]
reduced_df
# Out:
#          DATEDX  Age  Sex       Region  Alcohol  Khat  Tobacco  Weight_loss  \
# 0    12/14/2010   66    1       OROMIA        2     2        2            2
# 1     5/15/2010   66    2  ADDIS ABABA        2     1        2            1
# 2      2/2/2010   62    2  ADDIS ABABA        1     1        1            2
# 3     3/30/2010   62    2       OROMIA        1     2        2            1
# 4     4/15/2010   45    1       OROMIA        2     2        2            2
# ..          ...  ...  ...          ...      ...   ...      ...          ...
# 344    2/6/2016   55    2       OROMIA        2     1        2            2
# 345    2/9/2016   45    1        SNNPR        2     2        2            2
# 346   2/10/2016   67    2  ADDIS ABABA        2     1        2            2
# 347   3/21/2016   32    1       OROMIA        2     2        2            2
# 348    8/1/2016   58    2       AMHARA        1     1        1            2
#
#      Duration_all  Endoscopy  CT_Scan  Hist_grade  Dist_metas  Vomiting  \
# 0               3          1        1           1           4         2
# 1               8          1        2           5           4         1
# 2               1          1        1           5           1         2
# 3               9          1        2           5           2         2
# 4               5          1        1           5           3         1
# ..            ...        ...      ...         ...         ...       ...
# 344            12          1        1           1           3         2
# 345             4          1        1           5           4         2
# 346             4          2        1           1           4         2
# 347            11          1        1           2           3         2
# 348             3          1        1           1           3         2
#
#      Heart_burn  Cough  Chest_pain  Ba_swallow Date_death
# 0             2      2           2           1  4/23/2011
# 1             2      2           2           1        NaN
# 2             2      2           2           1        NaN
# 3             2      2           2           1        NaN
# 4             2      2           2           1        NaN
# ..          ...    ...         ...         ...        ...
# 344           2      2           2           1        NaN
# 345           2      2           2           1        NaN
# 346           2      2           2           1        NaN
# 347           2      2           2           1        NaN
# 348           2      2           2           1        NaN
#
# [349 rows x 19 columns]

# %%
# Rename the headers to be more explanatory
renamed_df = reduced_df.rename(columns={"DATEDX": "Diagnosis Date",
                                        "Weight_loss": "Weight Loss",
                                        "Duration_all": "Duration",
                                        "CT_Scan": "CT Scan",
                                        "Hist_grade": "Histologic Grade",
                                        "Dist_metas": "Distant Metastasis", 
                                       "Heart_burn": "Heart Burn",
                                       "Chest_pain": "Chest Pain",
                                       "Ba_swallow": "Barium Swallow",
                                       "Date_death": "Date of Death",})
renamed_df
# Out:
#     Diagnosis Date  Age  Sex       Region  Alcohol  Khat  Tobacco  \
# 0       12/14/2010   66    1       OROMIA        2     2        2
# 1        5/15/2010   66    2  ADDIS ABABA        2     1        2
# 2         2/2/2010   62    2  ADDIS ABABA        1     1        1
# 3        3/30/2010   62    2       OROMIA        1     2        2
# 4        4/15/2010   45    1       OROMIA        2     2        2
# ..             ...  ...  ...          ...      ...   ...      ...
# 344       2/6/2016   55    2       OROMIA        2     1        2
# 345       2/9/2016   45    1        SNNPR        2     2        2
# 346      2/10/2016   67    2  ADDIS ABABA        2     1        2
# 347      3/21/2016   32    1       OROMIA        2     2        2
# 348       8/1/2016   58    2       AMHARA        1     1        1
#
#      Weight Loss  Duration  Endoscopy  CT Scan  Histologic Grade  \
# 0              2         3          1        1                 1
# 1              1         8          1        2                 5
# 2              2         1          1        1                 5
# 3              1         9          1        2                 5
# 4              2         5          1        1                 5
# ..           ...       ...        ...      ...               ...
# 344            2        12          1        1                 1
# 345            2         4          1        1                 5
# 346            2         4          2        1                 1
# 347            2        11          1        1                 2
# 348            2         3          1        1                 1
#
#      Distant Metastasis  Vomiting  Heart Burn  Cough  Chest Pain  \
# 0                     4         2           2      2           2
# 1                     4         1           2      2           2
# 2                     1         2           2      2           2
# 3                     2         2           2      2           2
# 4                     3         1           2      2           2
# ..                  ...       ...         ...    ...         ...
# 344                   3         2           2      2           2
# 345                   4         2           2      2           2
# 346                   4         2           2      2           2
# 347                   3         2           2      2           2
# 348                   3         2           2      2           2
#
#      Barium Swallow Date of Death
# 0                 1     4/23/2011
# 1                 1           NaN
# 2                 1           NaN
# 3                 1           NaN
# 4                 1           NaN
# ..              ...           ...
# 344               1           NaN
# 345               1           NaN
# 346               1           NaN
# 347               1           NaN
# 348               1           NaN
#
# [349 rows x 19 columns]

# %%
# Labels for the sections of our pie chart
labels = ["Male", "Female"]

#male_df = renamed_df.loc[renamed_df['Sex'] ==1]
#female_df = renamed_df.loc[renamed_df['Sex'] == 2]

#print(len(male_df))
#print(len(female_df))

#renamed_df['Sex'].tolist().count(1)
# The values of each section of the pie chart
gender_count = [renamed_df['Sex'].tolist().count(1), renamed_df['Sex'].tolist().count(2)]

# The colors of each section of the pie chart
colors = ["blue", "red"]

# Tells matplotlib to separate the "Humans" section from the others
explode = (0.1, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(gender_count, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=14)
# Out:
# ([<matplotlib.patches.Wedge at 0x19d97736790>,
#   <matplotlib.patches.Wedge at 0x19d977441f0>],
#  [Text(-0.604463982510324, 1.0366403879107542, 'Male'),
#   Text(0.5540919839677964, -0.9502536889181916, 'Female')],
#  [Text(-0.352603989797689, 0.60470689294794, '59.0%'),
#   Text(0.30223199125516165, -0.5183201939553772, '41.0%')])

# %%
# Create an array that contains the number of patients each region has
patients_per_region_df = pd.DataFrame(renamed_df.groupby('Region')['Age'].count())
patients_chart = patients_per_region_df.plot(kind= 'bar', title= 'Patients Per Region')
patients_chart.set_xlabel('Region')
patients_chart.set_ylabel('Number of Patients')
plt.show()
plt.tight_layout()

# %%
# Age of patients vs time of death
death_patients = renamed_df[renamed_df['Date of Death'].notna()]
#death_patients_group = death_patients.groupby('Age').count()
death_patients_group = death_patients.groupby('Age').agg(count = ('Sex','count'))
death_patients_group.plot()

#x_axis = (0, 5,)
#x_axis
#death_patients_group
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# Age of patients vs time of death

death_patients = renamed_df[renamed_df['Date of Death'].notna()]
#death_patients_group = death_patients.groupby('Age').count()
#death_patients_group = death_patients.groupby('').agg(count = ('Sex','count'))
#death_patients
death_patients.reset_index()
death_patients
#for death_patient in death_patients:
#    date1= death_patient.loc[:, 'Diagnosis Date']
#date2= death_patient.loc[:,'Date of Death']
 #   mdate1 = datetime.datetime.strptime(date1, "%Y-%m-%d").date()
#rdate1 = datetime.datetime.strptime(date2, "%Y-%m-%d").date()
#delta =  (rdate1 - mdate1).days
 #   print(delta)
      # print(death_patient)
# Out:
#     Diagnosis Date  Age  Sex       Region  Alcohol  Khat  Tobacco  \
# 0       12/14/2010   66    1       OROMIA        2     2        2
# 13       6/28/2010   75    1  ADDIS ABABA        2     2        2
# 17       8/20/2010   60    1       OROMIA        2     2        2
# 21      10/25/2010   63    2       AMHARA        1     2        2
# 24      12/14/2010   75    2       OROMIA        2     2        2
# ..             ...  ...  ...          ...      ...   ...      ...
# 325      7/25/2016   65    1         AFAR        2     2        2
# 330      8/18/2016   60    2       OROMIA        2     1        1
# 335     10/19/2016   32    1  ADDIS ABABA        2     2        2
# 336     10/20/2016   35    2        SNNPR        2     2        2
# 341     11/30/2016   45    1       OROMIA        2     2        2
#
#      Weight Loss  Duration  Endoscopy  CT Scan  Histologic Grade  \
# 0              2         3          1        1                 1
# 13             2         3          1        2                 5
# 17             2         4          1        1                 5
# 21             1         4          2        2                 5
# 24             1         6          1        2                 1
# ..           ...       ...        ...      ...               ...
# 325            1         3          1        2                 5
# 330            1         3          1        1                 5
# 335            2         2          1        2                 5
# 336            2         4          1        1                 5
# 341            1         3          1        1                 5
#
#      Distant Metastasis  Vomiting  Heart Burn  Cough  Chest Pain  \
# 0                     4         2           2      2           2
# 13                    4         2           2      2           2
# 17                    1         2           2      2           2
# 21                    4         1           2      2           2
# 24                    1         2           2      2           2
# ..                  ...       ...         ...    ...         ...
# 325                   4         2           2      2           2
# 330                   2         2           2      2           2
# 335                   4         2           2      2           2
# 336                   2         2           2      2           2
# 341                   4         2           2      2           2
#
#      Barium Swallow Date of Death
# 0                 1     4/23/2011
# 13                1     9/27/2010
# 17                1    11/21/2010
# 21                1     2/24/2012
# 24                1     8/21/2013
# ..              ...           ...
# 325               1     10/8/2016
# 330               1    10/24/2016
# 335               1     3/18/2017
# 336               1
# 341               1
#
# [63 rows x 19 columns]
